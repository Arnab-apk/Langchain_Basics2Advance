# %%
import os 
api_key = os.getenv("TAVILY_API_KEY")
if api_key:
    os.environ["TAVILY_API_KEY"] = api_key
else:
    print("Warning: TAVILY_API_KEY not found in environment variables")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 import os
# ----> 2 os.environ["TAVILY_API_KEY"]=os.getenv("TAVILY_API_KEY")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\os.py:714, in _Environ.__setitem__(self, key, value)
#     712 def __setitem__(self, key, value):
#     713     key = self.encodekey(key)
# --> 714     value = self.encodevalue(value)
#     715     putenv(key, value)
#     716     self._data[key] = value
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\os.py:774, in _create_environ_mapping.<locals>.check_str(value)
#     772 def check_str(value):
#     773     if not isinstance(value, str):
# --> 774         raise TypeError("str expected, not %s" % type(value).__name__)
#     775     return value
#
# TypeError: str expected, not NoneType
